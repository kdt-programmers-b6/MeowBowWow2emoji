# %%
# %tensorflow_version 1.14
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.14`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 1.15.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/Shareddrives/[3-B]shared Drive/ugatit/UGATIT-tf'
# Out:
# /content/drive/Shareddrives/[3-B]shared Drive/ugatit/UGATIT-tf

# %%
# !python main.py --phase 'train' --dataset 'cat_final1' --epoch 100 --iteration 10000 --batch_size 1 --print_freq 1000 --save_freq 10000 --decay_flag True --decay_epoch 50 --lr 0.0001 --GP_ld 10 --adv_weight 1 --cycle_weight 10 --identity_weight 10 --cam_weight 1000 --gan_type 'lsgan' --smoothing True --ch 16 --n_res 4 --n_dis 6 --n_critic 1 --sn True --img_size 256 --img_ch 3 --augment_flag True --checkpoint_dir 'checkpoint_final_cat_v1' --result_dir 'results/cat_final_v1' --log_dir 'logs/cat_final_v1' --sample_dir 'samples/cat_final_v1'
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From main.py:88: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From main.py:88: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# 2022-05-04 06:02:01.294242: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# 2022-05-04 06:02:01.294532: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x23e1640 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...

# %%
#%cp -r testA '/content/drive/Shareddrives/[3-B]shared Drive/ugatit/UGATIT-tf/dataset/cat_final1'

# %%
# !python main.py --phase 'test' --dataset 'doggie2emoji' --epoch 70 --iteration 10000 --batch_size 1 --print_freq 1000 --save_freq 10000 --decay_flag True --decay_epoch 50 --lr 0.0001 --GP_ld 10 --adv_weight 1 --cycle_weight 10 --identity_weight 10 --cam_weight 1000 --gan_type 'lsgan' --smoothing True --ch 64 --n_res 4 --n_dis 6 --n_critic 1 --sn True --img_size 256 --img_ch 3 --augment_flag True --checkpoint_dir 'checkpoint0414_0622' --result_dir 'results' --log_dir 'logs' --sample_dir 'samples'
